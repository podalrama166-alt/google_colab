# %% [markdown]
# <a href="https://colab.research.google.com/github/podalrama166-alt/google_colab/blob/main/first_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s="python"
print(s)
print(s[0])
# Out:
# python
# p

# %%
text = "python"
print(text.center(20, "-"))
print(text.center(20))
print(text.ljust(20))
print(text.rjust(20))
print(text.zfill(10))
# Out:
# -------python-------
#        python
# python
#               python
# 0000python

# %%
age = 20
print("eligible") if age > 18 else print("not")
# Out:
# eligible

# %%
a=10
print(a)
print(id(a))

b=20
print(b, id(b))


a=20
print(a, id(a))
# Out:
# 10
# 11645640
# 20 11645960
# 20 11645960

# %%
student = ["Ravi", "ananya", "kiran"]
print(type(student))
for s in student:
  print(student)
for i in range(len(student)):     #for each loop
  print(i, student[i])

for j in "students":
  print(j, end=" ")
# Out:
# <class 'list'>
# ['Ravi', 'ananya', 'kiran']
# ['Ravi', 'ananya', 'kiran']
# ['Ravi', 'ananya', 'kiran']
# 0 Ravi
# 1 ananya
# 2 kiran
# s t u d e n t s
