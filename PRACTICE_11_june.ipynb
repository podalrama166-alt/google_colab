# %% [markdown]
# <a href="https://colab.research.google.com/github/podalrama166-alt/google_colab/blob/main/PRACTICE_11_june.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s_name = input("Enter your name : ")
print(s_name.upper())
# Out:
# Enter your name : podal
# PODAL

# %%
city_name = input("Enter a city name : ")
print(city_name)
print(f"the upper case of {city_name} is : ", city_name.upper())
print(f"the lower case of {city_name} is : ", city_name.lower())
print(f"the title case of {city_name} is : ", city_name.title())
# Out:
# Enter a city name : bhubaneswar
# bhubaneswar
# the upper case of bhubaneswar is :  BHUBANESWAR
# the lower case of bhubaneswar is :  bhubaneswar
# the title case of bhubaneswar is :  Bhubaneswar

# %%
s_len = input("Enter any string : ")
print(f"length of '{s_len}' is : ",len(s_len))
# Out:
# Enter any string : my name is podal rama
# length of 'my name is podal rama' is :  21

# %%
str1 = input("Enter a string :")
print(f"the first character of the string '{str1}' is : ",str1[0])
print(f"the last character of the string '{str1}' is : ",str1[-1])
# Out:
# Enter a string :odisha
# the first character of the string 'odisha' is :  o
# the last character of the string 'odisha' is :  a

# %%
str2 = input("Enetr a string : ")
print(f"The frequency of 'a' in the string '{str2}' is :",str2.count("a"))
# Out:
# Enetr a string : ramaprasad
# The frequency of 'a' in the string 'ramaprasad' is : 4

# %%
str3 = input("Enter a string about python which has the word python : ")
print(f" The original string is '{str3}' and the new string is :", str3.replace("python","AI"))
# Out:
# Enter a string about python which has the word python : python is advanced and high level language
#  The original string is 'python is advanced and high level language' and the new string is : AI is advanced and high level language

# %%
u_email = input("Enter your email : ")
print(u_email.endswith("@gmail.com"))
# Out:
# Enter your email : podalrama166@gmail.com
# True

# %%
num1 = input("Enter your mobile number : ")
print(num1.isnumeric())
# Out:
# Enter your mobile number : 8975764325
# True

# %%
str4 = input("Enter a string : ")
print(str4.isalpha())
# Out:
# Enter a string : podal
# True

# %%
list1 = "Apple,Mango,Banana,Orange"
print(list1.split(","))
# Out:
# ['Apple', 'Mango', 'Banana', 'Orange']

# %%
age = int(input("Enter your age :"))
if age >= 18 :
      print("You are eligible for vote")
else:
      print("You are not eligible for vote")
# Out:
# Enter your age :21
# You are eligible for vote

# %%
num2 = int(input("Enter a number : "))
if num2 > 0 :
  print(f"The {num2} is a positive number")
elif num2 < 0 :
  print(f"The {num2} is a negative number")
else:
  print(f"The {num2} is zero")
# Out:
# Enter a number : -243
# The -243 is a negative number

# %%
num1 = int(input("Enter first number : "))
num2 = int(input("Enter second number : "))
if num1 > num2 :
  print(f"The {num1} is greater than {num2}")
else:
  print(f"The {num2} is greater than {num1}")
# Out:
# Enter first number : 23
# Enter second number : 12
# The 23 is greater than 12

# %%
mark = int(input("Enter your mark :"))
if mark >= 90 :
  print("A Grade")
elif mark >= 75 :
  print("B Grade")
elif mark >= 50 :
  print("C Grade")
else :
  print("Fail")
# Out:
# Enter your mark :58
# C Grade

# %%
number = int(input("Enter a number : "))
if number % 2 == 0 :
  print(f"The {number} is even")
else :
  print(f"The {number} is odd")
# Out:
# Enter a number : 24
# The 24 is even

# %%
password = input("Enter your password : ")
if len(password) >= 8 :
  print("Strong password")
else :
  print("Weak password")

# %%
year = int(input("Enter a year : "))
if year % 100 == 0 :
  if year % 400 == 0 :
    print(f"{year} is a leap year")
  else :
    print(f"{year} is not a leap year")
elif year % 4 == 0 :
  print(f"{year} is a leap year")
else :
  print(f"{year} is not a leap year")
# Out:
# Enter a year : 2024
# 2024 is a leap year

# %%
num1 = int(input("Enter first number : "))
num2 = int(input("Enter second number : "))
num3 = int(input("Enter third number : "))
if num1 > num2 and num1 > num3 :
  print(f"{num1} is greater than {num2} and {num3}")
elif num2 > num1 and num2 > num3 :
  print(f"{num2} is greater than {num1} and {num3}")
else :
  print(f"{num3} is greater than {num1} and {num2}")
# Out:
# Enter first number : 12
# Enter second number : 32
# Enter third number : 25
# 32 is greater than 12 and 25

# %%
user_name = input("Enter your username : ")
password = input("Enter your password : ")
if user_name == "admin" and password == "1234" :
  print("Login Successful")
else :
  print("Invalid Credential")
# Out:
# Enter your username : admin
# Enter your password : 1234
# Login Successful

# %%
f_num = int(input("Enter first number : "))
s_num = int(input("Enter second number : "))
operate = input("Enter the operation : ")
if operate == "+" :
  print(f_num + s_num)
elif operate == "-" :
  print(f_num - s_num)
elif operate == "*" :
  print(f_num * s_num)
elif operate == "/" :
  print(f_num / s_num)
else :
  print("Invalid operation")
